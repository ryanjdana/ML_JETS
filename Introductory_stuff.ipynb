# %% [markdown]
# # This is the work done by Ryan Dana from June 4th-June 6th as some prep for an ML JET project.

# %% [markdown]
# ## Importing the Data

# %%
import pickle
class Particle(object):

    def __init__(self, pt, eta, phi):
        self.pt = pt
        self.eta = eta
        self.phi = phi


class Jet(Particle):

    def __init__(self, pt, eta, phi):
        super(Jet, self).__init__(pt, eta, phi)
        self.constituents = []

    def add_constituent(self, pt, eta, phi):
        p = Particle(pt, eta, phi)
        self.constituents.append(p)

def read():
    print 'reading...'
    jets = pickle.load(open("jets.pickled", "rb"))
    for j in jets:
        print j.pt
        
        sum_pt = 0
        for c in j.constituents:
            print ' - ', c.pt, c.eta, c.phi
            sum_pt += c.pt
        print ' checksum pt: ', j.pt/sum_pt
        
        
    print 'done'

if __name__ == '__main__':
    read()
# Out:
# reading...
# 107.473544655
#  -  15.0359104071 -0.353194421819 3.26211032453
#  -  12.1791840568 -0.323419279409 3.50280609641
#  -  8.66263290415 -0.52369562114 3.59166489802
#  -  8.084830126 -0.256927775651 3.61473511354
#  -  7.40425259913 -0.401038510786 3.51116690056
#  -  5.70850687986 -0.292078481355 3.59533589879
#  -  5.54275639349 -0.357768086844 3.26195063404
#  -  4.92946238315 -0.637142123371 3.47927958657
#  -  4.88254788419 -0.524313252759 3.5943263626
#  -  4.86853115857 -0.541435281401 3.47470954543
#  -  2.87660602096 -0.231603135807 3.4991946194
#  -  2.77453108001 -0.709521349523 3.54627602042
#  -  2.71771727878 -0.145700497304 3.49007935109
#  -  2.36540819263 -0.579370610966 3.55595029745
#  -  2.10956710778 -0.639756399578 3.41889753854
#  -  2.0970059088 -0.591646888667 3.69354949912
#  -  2.03350720413 -0.753901899646 3.50279648699
#  -  1.9100201639 -0.322169738502 3.5852958252
#  -  1.6874643819 -0.327443577147 3.47330384168
# ...

# %% [markdown]
# Here is a Histogram Distribution of the amount of Z

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython import display
jets = pickle.load(open("jets.pickled", "rb"))
z=[]


for j in jets:
    for c in j.constituents:
        z.append(c.pt/j.pt)
z=np.array(z)
plt.yscale('log', nonposy='clip')
plt.hist(z, bins=11)
plt.show()

# %% [markdown]
# Here is a 2dhistogram distribution of phi and eta

# %%
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
import numpy as np


plt.hist2d(phi, eta, bins=40, )

plt.colorbar()
plt.show()

# %% [markdown]
# Setting up data...

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython import display
jets = pickle.load(open("jets.pickled", "rb"))
z=[]
eta=[]
phi=[]
pt=[]
axes=[]
deta=[]
dphi=[]
jetphi=[]
jeteta=[]
jetz=[]
length=[]
i=0
for j in jets:
    for c in j.constituents:
        Dell=np.sqrt((j.eta-c.eta)**2+(j.phi-c.phi)**2)
        if Dell<.4:
            z.append(c.pt/j.pt)
            zsample.append(c.pt/j.pt)
            eta.append(c.eta)
            phi.append(c.phi)
            pt.append(c.pt)
            dphi.append(j.phi-c.phi)
            deta.append(j.eta-c.eta)
            i+=1
    jetphi.append(dphi)
    jeteta.append(deta)
    jetz.append(zsample)
    zsample=[]
    dphi=[]
    deta=[]
    length.append(i)
    i=0

z=np.array(z)
phi=np.array(phi)

eta=np.array(eta)

# %%
plt.figure(figsize=(20,20))
plt.hist2d(px, py, bins=40,range=((-1,1),(-1,1)) )
plt.title("Momentum in X vs. Momentum in Y",size=30)
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.hist2d(dphi, deta, bins=100,range=((-.4,.4),(-.4,.4)) )
plt.title("(ALL SAMPLES) Position in eta vs. Position in phi",size=30)
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.title("(ALL SAMPLES) Position in eta vs. Position in phi with weights of Transverse Momentum",size=30)
plt.hist2d(dphi, deta, bins=100,range=((-.4,.4),(-.4,.4)),weights=z )

plt.colorbar()
plt.show()

# %%
xrand=np.random.uniform(-.4,.4,20035)
yrand=np.random.uniform(-.4,.4,20035)
zrand=np.random.uniform(0,1,20035)
plt.figure(figsize=(20,20))
plt.title("randomly generated sample with random weights",size=30)
plt.hist2d(xrand, yrand, bins=100,range=((-.4,.4),(-.4,.4)),weights=zrand )

plt.colorbar()
plt.show()

# %%
xrand=np.random.uniform(-.4,.4,20035)
yrand=np.random.uniform(-.4,.4,20035)
zrand=np.random.uniform(0,1,20035)
plt.figure(figsize=(20,20))
plt.title("randomly generated sample with original z weights",size=30)
plt.hist2d(xrand, yrand, bins=100,range=((-.4,.4),(-.4,.4)),weights=z )

plt.colorbar()
plt.show()

# %%
length=np.array(length)
print(type(lenn))
def Gaussian(mean,variance):
    constant=1/(np.sqrt(2*np.pi*variance))
    constant2=np.e**(-(length-mean)**2/variance)
    return constant*constant2
plt.scatter(length,Gaussian(21.045,52.478))
plt.title("fitting histogram of averages to guassian")
plt.show()
# Out:
# <type 'list'>

# %%
plt.hist(length,20)
plt.title("Same graph but histogram")
plt.show()

# %% [markdown]
# Helper function that Plots the Jet so you can call this function whenever you want

# %%
def PlotJet(jeteta,jetphi,jetz,title):
    plt.figure(figsize=(20,20))
    plt.hist2d(jeteta, jetphi, bins=10,range=((-.4,.4),(-.4,.4)), weights=jetz )
    if title==0:
        plt.title('Real Jet',size=30)
    if title==1:
        plt.title('Fake Jet',size=30)
    plt.colorbar()
    plt.show()

# %%
## Organizing data

TrainJet=[jeteta[0:476],jetphi[0:476],jetz[0:476]]
TestJet=[jeteta[476:952],jetphi[476:952],jetz[476:952]]

# %%
randeta=[]
randphi=[]
innerrandz=[]
randz=[]
i=0
totleft=1
while i<952:
    random=np.random.normal(21.0451680672,7.2441701983394697)
    random=abs(int(round(random)))
    if random==0:
        random=1
    randeta.append(np.random.uniform(-.4,.4,random))
    randphi.append(np.random.uniform(-np.pi,np.pi,random))
    xx=np.random.uniform(0,1,random)
    for item in xx:
            float(item)
    randz.append(xx/random)
    i+=1
randz=np.array(randz)    

i=0

TrainfakeJet=[randeta[0:476],randphi[0:476],randz[0:476]]
TrainfakeJet=[randeta[476:952],randphi[476:952],randz[476:952]]

# %%
## Histogram Data for Z
histrandz=[]
i=0
while i<952:
    histrandz.append(np.mean(randz[i]))
    i+=1

plt.hist(histrandz,100,range=(0,.3),color='gold')
plt.title("Random Z histogram")


i=0
histjetz=[]
while i<952:
    histjetz.append(np.mean(jetz[i]))
    i+=1
plt.hist(histjetz,100,range=(0,.3),color='blue')
plt.title("Jet Z Histogram")
plt.show()


## Histogram Data for R
histrandR=[]
i=0
while i<952:
    histrandR.append(np.mean(np.sqrt(np.square(randeta[i])+np.square(randphi[i]))))
    i+=1

plt.hist(histrandR,100,color='gold')
plt.title("Random R histogram")

histjetR=[]

jeteta=np.array(jeteta)
jetphi=np.array(jetphi)
i=0
while i<952-1:
    histjetR.append(np.mean(np.sqrt(np.square(jeteta[i])+np.square(jetphi[i]))))
    i+=1

plt.hist(histjetR,100,color='blue')

plt.title("jet R histogram")
plt.show()

# %% [markdown]
# Now for some MACHINE LEARNING

# %%
##ORGANIZING DATA FOR AVERAGES
i=0
FullTrainx=[]
FullTrainy=[]
FullTestx=[]
FullTesty=[]
while i<476:
    FullTrainx.append([np.mean(jetz[i]),np.mean(np.sqrt(np.square(jeteta[i])+np.square(jetphi[i]))),len(jetz[i])])
    FullTrainy.append(0)
    FullTrainx.append([np.mean(randz[i]),np.mean(np.sqrt(np.square(randeta[i])+np.square(randphi[i]))),len(randz[i])])
    FullTrainy.append(1)
    i+=1
while i<952:
    FullTestx.append([np.mean(jetz[i]),np.mean(np.sqrt(np.square(jeteta[i])+np.square(jetphi[i]))),len(jetz[i])])
    FullTesty.append(0)
    FullTestx.append([np.mean(randz[i]),np.mean(np.sqrt(np.square(randeta[i])+np.square(randphi[i]))),len(randz[i])])
    FullTesty.append(1)
    i+=1

FullTrainx=np.array(FullTrainx)
FullTrainy=np.array(FullTrainy)
FullTestx=np.array(FullTestx)
FullTesty=np.array(FullTesty)

# %%
import sklearn
from sklearn import neural_network
clf = sklearn.neural_network.MLPClassifier()
clf.fit(FullTrainx, FullTrainy)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
y_predict=clf.predict(FullTestx)
sklearn.metrics.confusion_matrix(FullTesty,y_predict)
# Out:
# array([[476,   0],
#        [  0, 476]])

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Compute confusion matrix
cnf_matrix = confusion_matrix(FullTesty, y_predict)
np.set_printoptions(precision=3)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes='01',
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes="01", normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[476   0]
#  [  0 476]]
# Normalized confusion matrix
# [[ 1.  0.]
#  [ 0.  1.]]
